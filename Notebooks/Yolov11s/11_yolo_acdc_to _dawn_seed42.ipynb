# %% [markdown]
# # **Cross-Dataset Experiment (ACDC → DAWN) — YOLOv11s**
# - Training YOLOv11s on the ACDC dataset using COCO pretrained weights
# - Evaluating the trained model on the global DAWN test set
# - Performing weather-specific evaluations on the fog, rain, and snow subsets of the DAWN dataset

# %% [markdown]
# ## Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install Ultralytics

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.9 MB/s eta 0:00:00

# %% [markdown]
# ## Import librairies

# %%
from ultralytics import YOLO
from pathlib import Path
import pandas as pd
import time
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## Path

# %%
PROJECT_ROOT = Path("/content/drive/MyDrive/Dissertation")

RUNS_ROOT = PROJECT_ROOT / "Runs"
DATASETS_ROOT = PROJECT_ROOT / "Datasets" / "processed"

# ACDC (training dataset)
ACDC_YOLO_ROOT = DATASETS_ROOT / "acdc_yolo"

# DAWN (evaluation) dataset)
DAWN_YOLO_ROOT = DATASETS_ROOT / "dawn_yolo"

# %% [markdown]
# ## YAML Files

# %%
# ACDC training YAML
ACDC_DATA_YAML = ACDC_YOLO_ROOT / "acdc.yaml"

# DAWN  evaluation YAMLs
DAWN_GLOBAL_YAML = DAWN_YOLO_ROOT / "dataset.yaml"
DAWN_FOG_YAML    = DAWN_YOLO_ROOT / "fog_only.yaml"
DAWN_RAIN_YAML   = DAWN_YOLO_ROOT / "rain_only.yaml"
DAWN_SNOW_YAML   = DAWN_YOLO_ROOT / "snow_only.yaml"

# %% [markdown]
# ## Classes

# %%
CLASS_NAMES = [
    "person",
    "bicycle",
    "car",
    "motorcycle",
    "bus",
    "truck"
]

# %% [markdown]
# ## Experiment Settings

# %%
SEED = 42

MODEL_NAME = "yolo11s.pt"

EXPERIMENT_NAME = f"acdc_to_dawn_yolo11s_seed{SEED}"

# %% [markdown]
# ## Training

# %%
model = YOLO(MODEL_NAME)

train_results = model.train(
    data=str(ACDC_DATA_YAML),

    # Training
    epochs=100,
    patience=10,

    # Image / batch
    imgsz=640,
    batch=16,

    # Reproducibility
    seed=SEED,
    deterministic=True,
    pretrained=True,

    # Validation
    val=True,

    # Workers
    workers=2,

    # Output
    project=str(RUNS_ROOT / "yolo"),
    name=EXPERIMENT_NAME,
    exist_ok=True
)
# Out:
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/Dissertation/Datasets/processed/acdc_yolo/acdc.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=acdc_to_dawn_yolo11s_seed42, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/Dissertation/Runs/yolo, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    821730  ultralytics.nn.modules.head.Detect           [6, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,430,114 parameters, 9,430,098 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.6±0.2 ms, read: 123.1±118.9 MB/s, size: 455.7 KB)
# train: Scanning /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Datasets/processed/acdc_yolo/labels/train.cache... 1620 images, 29 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1620/1620 453.0Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.7±0.1 ms, read: 109.5±39.2 MB/s, size: 355.2 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Datasets/processed/acdc_yolo/labels/val.cache... 540 images, 5 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 540/540 43.6Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.93G      1.549      2.932      1.082         16        640: 6% ╸─────────── 6/102 3.6it/s 16.3s<27.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2688/2203072894.py in <cell line: 0>()
#       1 model = YOLO(MODEL_NAME)
#       2
# ----> 3 train_results = model.train(
#       4     data=str(ACDC_DATA_YAML),
#       5
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     790             self.model = self.trainer.model
#     791
# --> 792         self.trainer.train()
#     793         # Update model and cfg after training
#     794         if RANK in {-1, 0}:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in train(self)
#     244
#     245         else:
# --> 246             self._do_train()
#     247
#     248     def _setup_scheduler(self):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in _do_train(self)
#     419                 pbar = TQDM(enumerate(self.train_loader), total=nb)
#     420             self.tloss = None
# --> 421             for i, batch in pbar:
#     422                 self.run_callbacks("on_train_batch_start")
#     423                 # Warmup
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/tqdm.py in __iter__(self)
#     348
#     349         try:
# --> 350             for item in self.iterable:
#     351                 yield item
#     352                 self.update(1)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/data/build.py in __iter__(self)
#      80         """Create an iterator that yields indefinitely from the underlying iterator."""
#      81         for _ in range(len(self)):
# ---> 82             yield next(self.iterator)
#      83
#      84     def __del__(self):
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     739                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740                 self._reset()  # type: ignore[call-arg]
# --> 741             data = self._next_data()
#     742             self._num_yielded += 1
#     743             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1522                     "Invalid iterator state: shutdown or no outstanding tasks when fetching next data"
#    1523                 )
# -> 1524             idx, data = self._get_data()
#    1525             self._tasks_outstanding -= 1
#    1526             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1471         elif self._pin_memory:
#    1472             while self._pin_memory_thread.is_alive():
# -> 1473                 success, data = self._try_get_data()
#    1474                 if success:
#    1475                     return data
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1308         #   (bool: whether successfully get data, any: data if successful else None)
#    1309         try:
# -> 1310             data = self._data_queue.get(timeout=timeout)
#    1311             return (True, data)
#    1312         except Exception as e:
#
# /usr/lib/python3.12/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     357             else:
#     358                 if timeout > 0:
# --> 359                     gotit = waiter.acquire(True, timeout)
#     360                 else:
#     361                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Load best model

# %%
BEST_MODEL_PATH = (
    RUNS_ROOT
    / "yolo"
    / EXPERIMENT_NAME
    / "weights"
    / "best.pt"
)

best_model = YOLO(str(BEST_MODEL_PATH))

print(f"\nBest model loaded from:\n{BEST_MODEL_PATH}")
# Out:
# Best model loaded from:
# /content/drive/MyDrive/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42/weights/best.pt

# %% [markdown]
# ## Evaluation Function

# %%
OUTPUT_DIR = RUNS_ROOT / "yolo" / EXPERIMENT_NAME / "cross_dataset_eval_dawn"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print(f"Evaluation outputs will be saved to:\n{OUTPUT_DIR}")
# Out:
# Evaluation outputs will be saved to:
# /content/drive/MyDrive/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42/cross_dataset_eval_dawn

# %%
def evaluate_split(model, yaml_path, split_name):

    print(f"\nEvaluating ACDC -> DAWN on: {split_name}")

    metrics = model.val(
        data=str(yaml_path),
        split="test",
        imgsz=640,
        batch=16,
        device=0,
        verbose=False,
        project=str(OUTPUT_DIR),
        name=f"eval_{split_name}",
        exist_ok=True
    )

    precision = float(metrics.box.mp)
    recall = float(metrics.box.mr)

    f1_score = (
        2 * precision * recall / (precision + recall)
        if (precision + recall) > 0
        else 0.0
    )

    preprocess_ms = float(metrics.speed.get("preprocess", 0.0))
    inference_ms = float(metrics.speed.get("inference", 0.0))
    postprocess_ms = float(metrics.speed.get("postprocess", 0.0))

    total_ms_per_image = preprocess_ms + inference_ms + postprocess_ms
    fps = 1000 / total_ms_per_image if total_ms_per_image > 0 else 0.0

    return {
        "source_train_dataset": "ACDC",
        "target_test_dataset": "DAWN",
        "model": "YOLOv11s",
        "experiment": "ACDC->DAWN",
        "seed": SEED,
        "condition": split_name,

        "mAP50-95": float(metrics.box.map),
        "mAP50": float(metrics.box.map50),
        "mAP75": float(metrics.box.map75),

        "Precision": precision,
        "Recall": recall,
        "F1-score": f1_score,

        "Preprocess_ms_per_image": preprocess_ms,
        "Inference_ms_per_image": inference_ms,
        "Postprocess_ms_per_image": postprocess_ms,
        "Total_ms_per_image": total_ms_per_image,
        "FPS": fps,
    }

# %% [markdown]
# ## Global and weather-specific evaluation

# %%
import yaml

for name, yaml_path in evaluation_configs:
    print("\n", name, yaml_path)
    with open(yaml_path, "r") as f:
        data = yaml.safe_load(f)
    print(data)
# Out:
#  global /content/drive/MyDrive/Dissertation/Datasets/processed/dawn_yolo/dataset.yaml
# {'path': '/content/drive/MyDrive/Dissertation/Datasets/processed/dawn_yolo', 'train': 'images/train', 'val': 'images/val', 'nc': 6, 'names': ['person', 'bicycle', 'car', 'motorcycle', 'bus', 'truck'], 'test': 'images/test'}
#
#  fog /content/drive/MyDrive/Dissertation/Datasets/processed/dawn_yolo/fog_only.yaml
# {'path': '/content/drive/MyDrive/Dissertation/Datasets/processed/dawn_yolo', 'train': 'images/train', 'val': 'images/test_fog', 'nc': 6, 'names': ['person', 'bicycle', 'car', 'motorcycle', 'bus', 'truck']}
#
#  rain /content/drive/MyDrive/Dissertation/Datasets/processed/dawn_yolo/rain_only.yaml
# {'path': '/content/drive/MyDrive/Dissertation/Datasets/processed/dawn_yolo', 'train': 'images/train', 'val': 'images/test_rain', 'nc': 6, 'names': ['person', 'bicycle', 'car', 'motorcycle', 'bus', 'truck']}
#
#  snow /content/drive/MyDrive/Dissertation/Datasets/processed/dawn_yolo/snow_only.yaml
# {'path': '/content/drive/MyDrive/Dissertation/Datasets/processed/dawn_yolo', 'train': 'images/train', 'val': 'images/test_snow', 'nc': 6, 'names': ['person', 'bicycle', 'car', 'motorcycle', 'bus', 'truck']}

# %%
import yaml

weather_yaml_updates = {
    DAWN_FOG_YAML: "images/test_fog",
    DAWN_RAIN_YAML: "images/test_rain",
    DAWN_SNOW_YAML: "images/test_snow",
}

for yaml_path, test_path in weather_yaml_updates.items():
    with open(yaml_path, "r") as f:
        data = yaml.safe_load(f)

    data["test"] = test_path

    with open(yaml_path, "w") as f:
        yaml.dump(data, f, sort_keys=False)

    print(f"Updated {yaml_path}: test = {test_path}")
# Out:
# Updated /content/drive/MyDrive/Dissertation/Datasets/processed/dawn_yolo/fog_only.yaml: test = images/test_fog
# Updated /content/drive/MyDrive/Dissertation/Datasets/processed/dawn_yolo/rain_only.yaml: test = images/test_rain
# Updated /content/drive/MyDrive/Dissertation/Datasets/processed/dawn_yolo/snow_only.yaml: test = images/test_snow

# %%
split="test"

# %%
evaluation_configs = [
    ("global", DAWN_GLOBAL_YAML),
    ("fog", DAWN_FOG_YAML),
    ("rain", DAWN_RAIN_YAML),
    ("snow", DAWN_SNOW_YAML),
]

all_results = []

for split_name, yaml_path in evaluation_configs:

    print(f"\nEvaluating ACDC -> DAWN on: {split_name}")

    result = evaluate_split(
        model=best_model,
        yaml_path=yaml_path,
        split_name=split_name
    )

    all_results.append(result)
# Out:
# Evaluating ACDC -> DAWN on: global
#
# Evaluating ACDC -> DAWN on: global
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# val: Fast image access ✅ (ping: 6.8±14.0 ms, read: 31.1±40.5 MB/s, size: 171.9 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Datasets/processed/dawn_yolo/labels/test.cache... 140 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 140/140 53.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.1it/s 1.8s
#                    all        140        920      0.358      0.161      0.184      0.116
# Speed: 0.6ms preprocess, 1.6ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42/cross_dataset_eval_dawn/eval_global
#
# Evaluating ACDC -> DAWN on: fog
#
# Evaluating ACDC -> DAWN on: fog
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# val: Fast image access ✅ (ping: 0.4±0.1 ms, read: 69.0±43.9 MB/s, size: 106.8 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Datasets/processed/dawn_yolo/labels/test_fog.cache... 60 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 60/60 14.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all         60        412      0.314      0.129      0.134     0.0839
# Speed: 0.6ms preprocess, 2.6ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42/cross_dataset_eval_dawn/eval_fog
#
# Evaluating ACDC -> DAWN on: rain
#
# Evaluating ACDC -> DAWN on: rain
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# val: Fast image access ✅ (ping: 0.4±0.1 ms, read: 75.7±26.0 MB/s, size: 127.3 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Datasets/processed/dawn_yolo/labels/test_rain.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 12.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.7it/s 1.1s
#                    all         40        250       0.64       0.26       0.27      0.189
# Speed: 0.7ms preprocess, 14.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42/cross_dataset_eval_dawn/eval_rain
#
# Evaluating ACDC -> DAWN on: snow
#
# Evaluating ACDC -> DAWN on: snow
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# val: Fast image access ✅ (ping: 0.4±0.1 ms, read: 62.5±16.8 MB/s, size: 104.6 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Datasets/processed/dawn_yolo/labels/test_snow.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 14.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.3it/s 0.9s
#                    all         40        258       0.71       0.24      0.292      0.181
# Speed: 1.1ms preprocess, 2.9ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42/cross_dataset_eval_dawn/eval_snow

# %% [markdown]
# ## Results dataframe

# %%
results_df = pd.DataFrame(all_results)

print("ACDC -> DAWN YOLOv11s RESULTS")

display(results_df)
# Out:
# ACDC -> DAWN YOLOv11s RESULTS
#   source_train_dataset target_test_dataset     model  experiment  seed  \
# 0                 ACDC                DAWN  YOLOv11s  ACDC->DAWN    42
# 1                 ACDC                DAWN  YOLOv11s  ACDC->DAWN    42
# 2                 ACDC                DAWN  YOLOv11s  ACDC->DAWN    42
# 3                 ACDC                DAWN  YOLOv11s  ACDC->DAWN    42
#
#   condition  mAP50-95     mAP50     mAP75  Precision    Recall  F1-score  \
# 0    global  0.115986  0.183843  0.124351   0.358106  0.161090  0.222217
# 1       fog  0.083863  0.133888  0.078216   0.313907  0.128695  0.182549
# 2      rain  0.188633  0.269746  0.237222   0.639984  0.259542  0.369312
# 3      snow  0.180679  0.292433  0.201076   0.710224  0.239784  0.358524
#
#    Preprocess_ms_per_image  Inference_ms_per_image  Postprocess_ms_per_image  \
# 0                 0.598128                1.629793                  1.094824
# 1                 0.554930                2.639025                  1.916240
# 2                 0.650509               14.033249                  1.238229
# 3                 1.064600                2.879349                  1.339176
#
#    Total_ms_per_image         FPS
# 0            3.322744  300.956043
# 1            5.110194  195.687272
# 2           15.921987   62.806232
# 3            5.283125  189.281908

# %% [markdown]
# ## Save results

# %%
RESULTS_DIR = (
    RUNS_ROOT
    / "yolo"
    / EXPERIMENT_NAME
)

RESULTS_DIR.mkdir(parents=True, exist_ok=True)

csv_path = RESULTS_DIR / "acdc_to_dawn_yolo11s_results.csv"
json_path = RESULTS_DIR / "acdc_to_dawn_yolo11s_results.json"
xlsx_path = RESULTS_DIR / "acdc_to_dawn_yolo11s_results.xlsx"

results_df.to_csv(csv_path, index=False)

results_df.to_json(
    json_path,
    orient="records",
    indent=4
)

results_df.to_excel(
    xlsx_path,
    index=False
)

print("\nResults saved:")
print(f"CSV  : {csv_path}")
print(f"JSON : {json_path}")
print(f"XLSX : {xlsx_path}")
# Out:
# Results saved:
# CSV  : /content/drive/MyDrive/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42/acdc_to_dawn_yolo11s_results.csv
# JSON : /content/drive/MyDrive/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42/acdc_to_dawn_yolo11s_results.json
# XLSX : /content/drive/MyDrive/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42/acdc_to_dawn_yolo11s_results.xlsx

# %% [markdown]
# ## Save summary

# %%
summary_path = RESULTS_DIR / "experiment_summary.txt"

with open(summary_path, "w") as f:
    f.write("YOLOv11s Cross-Dataset Experiment\n")
    f.write(f"Experiment: {EXPERIMENT_NAME}\n")
    f.write("Direction: ACDC -> DAWN\n")
    f.write("Source training dataset: ACDC\n")
    f.write("Target evaluation dataset: DAWN\n")
    f.write("Model: YOLOv11s\n")
    f.write(f"Seed: {SEED}\n")
    f.write("Training epochs: 100\n")
    f.write("Early stopping patience: 10\n")
    f.write("Image size: 640\n")
    f.write("Batch size: 16\n")
    f.write("Evaluation: global + fog + rain + snow\n")
    f.write(f"\nBest model path:\n{BEST_MODEL_PATH}\n")
    f.write(f"\nResults CSV:\n{csv_path}\n")
    f.write(f"\nResults JSON:\n{json_path}\n")
    f.write(f"\nResults XLSX:\n{xlsx_path}\n")

print(f"Summary saved: {summary_path}")
# Out:
# Summary saved: /content/drive/MyDrive/Dissertation/Runs/yolo/acdc_to_dawn_yolo11s_seed42/experiment_summary.txt
