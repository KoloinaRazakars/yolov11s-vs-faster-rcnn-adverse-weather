# %% [markdown]
# # Ultralytics YOLO Setup
#
# This notebook installs and verifies the **Ultralytics YOLO** framework used for all YOLO-based experiments.
# It must be run **after** `00_environment_setup.ipynb` and **before** any YOLO training or inference notebook.
#
# **What this notebook does:**
# - Mounts Google Drive
# - Verifies GPU, CUDA, and PyTorch availability
# - Installs the Ultralytics package
# - Runs built-in Ultralytics environment checks
# - Loads a lightweight YOLO model and runs a quick inference test
# - Confirms the YOLO pipeline is ready for experimentation

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Base Imports

# %%
import sys
import platform
from pathlib import Path
import torch

# %% [markdown]
# ## Environment Check

# %%
print("ULTRALYTICS SETUP: ENVIRONMENT CHECK")
print("Python version :", sys.version)
print("Platform       :", platform.platform())
print("PyTorch version:", torch.__version__)
print("CUDA available :", torch.cuda.is_available())
print("CUDA version   :", torch.version.cuda)

if torch.cuda.is_available():
    print("GPU name       :", torch.cuda.get_device_name(0))
    print("GPU count      :", torch.cuda.device_count())
else:
    print("⚠️ WARNING: No GPU detected. Session running on CPU.")
# Out:
# ULTRALYTICS SETUP: ENVIRONMENT CHECK
# Python version : 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Platform       : Linux-6.6.113+-x86_64-with-glibc2.35
# PyTorch version: 2.10.0+cu128
# CUDA available : True
# CUDA version   : 12.8
# GPU name       : Tesla T4
# GPU count      : 1

# %% [markdown]
# ### GPU Hardware Details

# %%
# !nvidia-smi
# Out:
# Wed Apr  1 15:39:35 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8             11W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## Install Ultralytics

# %%
# !pip install -q --upgrade pip
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 29.9 MB/s eta 0:00:00

# %% [markdown]
# ## Import Ultralytics

# %%
import ultralytics
from ultralytics import YOLO

print("Ultralytics version:", ultralytics.__version__)
print("YOLO imported successfully.")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics version: 8.4.33
# YOLO imported successfully.

# %% [markdown]
# ## Ultralytics Built-in Checks

# %%
# !yolo checks
# Out:
# Ultralytics 8.4.33 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.7/112.6 GB disk)
#
# OS                     Linux-6.6.113+-x86_64-with-glibc2.35
# Environment            Colab
# Python                 3.12.13
# Install                pip
# Path                   /usr/local/lib/python3.12/dist-packages/ultralytics
# RAM                    12.67 GB
# Disk                   43.7/112.6 GB
# CPU                    Intel Xeon CPU @ 2.00GHz
# CPU count              2
# GPU                    Tesla T4, 14913MiB
# GPU count              1
# CUDA                   12.8
#
# numpy                  ✅ 2.0.2>=1.23.0
# matplotlib             ✅ 3.10.0>=3.3.0
# opencv-python          ✅ 4.13.0.92>=4.6.0
# pillow                 ✅ 11.3.0>=7.1.2
# pyyaml                 ✅ 6.0.3>=5.3.1
# requests               ✅ 2.32.4>=2.23.0
# scipy                  ✅ 1.16.3>=1.4.1
# torch                  ✅ 2.10.0+cu128>=1.8.0
# ...

# %% [markdown]
# ## Project Configuration

# %%
PROJECT_ROOT = Path("/content/drive/MyDrive/Colab Notebooks/Dissertation")
DEVICE = 0 if torch.cuda.is_available() else "cpu"

print("PROJECT_ROOT:", PROJECT_ROOT)
print("YOLO device :", DEVICE)
# Out:
# PROJECT_ROOT: /content/drive/MyDrive/Colab Notebooks/Dissertation
# YOLO device : 0

# %% [markdown]
# ## Load YOLO model

# %%
model = YOLO("yolo11m.pt")
print("YOLO model loaded successfully.")
# Out:
# ...
# YOLO model loaded successfully.

# %% [markdown]
# ## Model Architecture Info

# %%
model.info()
# Out:
# YOLO11n summary: 181 layers, 2,624,080 parameters, 0 gradients, 6.6 GFLOPs
# (181, 2624080, 0, 6.614336)

# %% [markdown]
# ## Quick Inference Test

# %%
results = model.predict(
    source="https://ultralytics.com/images/bus.jpg",
    save=False,
    device=DEVICE,
    verbose=False
)

print(" Inference test completed successfully.")
# Out:
# ...
#  Inference test completed successfully.

# %% [markdown]
# ## **Setup summary**

# %%
print("\n ULTRALYTICS SETUP COMPLETE")
print(f"PyTorch version : {torch.__version__}")
print(f"CUDA available  : {torch.cuda.is_available()}")
print(f"Device          : {DEVICE}")
print(f"Project root    : {PROJECT_ROOT}")
print("\n Ultralytics environment is ready.")
# Out:
#  ULTRALYTICS SETUP COMPLETE
# PyTorch version : 2.10.0+cu128
# CUDA available  : True
# Device          : 0
# Project root    : /content/drive/MyDrive/Colab Notebooks/Dissertation
#
#  Ultralytics environment is ready.
