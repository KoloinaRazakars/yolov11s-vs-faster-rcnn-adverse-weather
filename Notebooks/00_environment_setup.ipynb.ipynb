# %% [markdown]
# # **Environment Setup**
# Common environment setup for dissertation experiments ( for YOLO vs Faster R-CNN under adverse weather)
#
# This notebook initialises the shared environment for all experiments in this dissertation.
# It must be **run first** before any other notebook.
#
# **What this notebook does:**
# - Mounts Google Drive
# - Verifies GPU, CUDA, and PyTorch availability
# - Installs all required dependencies
# - Defines and creates the full project folder structure
# - Sets global random seeds for reproducibility
# - Confirms the environment is ready for experimentation

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Base Imports

# %%
import os
import sys
import random
import platform
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install -q opencv-python matplotlib pyyaml tqdm pycocotools pandas seaborn
# !pip install -q jedi

# %% [markdown]
# ## System & GPU Verification

# %%
import torch

print("CHECK ENVIRONNEMENT")
print("Torch version:", torch.__version__)
print("CUDA disponible:", torch.cuda.is_available())
print("Torch CUDA version:", torch.version.cuda)

if torch.cuda.is_available():
    print("Nom GPU:", torch.cuda.get_device_name(0))
    print("Nombre de GPU:", torch.cuda.device_count())
else:
    print("⚠️ GPU non détecté")
# Out:
# CHECK ENVIRONNEMENT
# Torch version: 2.10.0+cu128
# CUDA disponible: True
# Torch CUDA version: 12.8
# Nom GPU: Tesla T4
# Nombre de GPU: 1

# %% [markdown]
# ### GPU Hardware

# %%
# !nvidia-smi
# Out:
# Wed Apr  1 14:49:13 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## Install Common Depedencies

# %%
# !pip install -q --upgrade pip setuptools wheel
# !pip install -q opencv-python matplotlib pyyaml tqdm pycocotools pandas seaborn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 69.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 68.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.

# %% [markdown]
# ## Imports post-installation

# %%
import cv2
import yaml
import pandas as pd
from tqdm import tqdm

print("OpenCV version :", cv2.__version__)
print("NumPy version  :", np.__version__)
print("Pandas version :", pd.__version__)
# Out:
# OpenCV version : 4.13.0
# NumPy version  : 2.0.2
# Pandas version : 2.2.2

# %% [markdown]
# ## Project Root

# %%
PROJECT_ROOT = Path("/content/drive/MyDrive/Colab Notebooks/Dissertation")

DATASETS_DIR = PROJECT_ROOT / "Datasets"
RESULTS_DIR = PROJECT_ROOT / "Results"
RUNS_DIR = PROJECT_ROOT / "Runs"
MODELS_DIR = PROJECT_ROOT / "Models"
LOGS_DIR = PROJECT_ROOT / "Logs"

# %% [markdown]
# ## Create Folders

# %%
for folder in [DATASETS_DIR, RESULTS_DIR, RUNS_DIR, MODELS_DIR, LOGS_DIR]:
    folder.mkdir(parents=True, exist_ok=True)

print("Project folders created/verified successfully.")
# Out:
# Project folders created/verified successfully.

# %%
# Raw datasets
RAW_DATASETS_DIR = DATASETS_DIR / "Raw"
RAW_DAWN_DIR = RAW_DATASETS_DIR / "DAWN"
RAW_ACDC_DIR = RAW_DATASETS_DIR / "ACDC"
RAW_BDD100K_DIR = RAW_DATASETS_DIR / "BDD100K"

# Processed datasets
PROCESSED_DATASETS_DIR = DATASETS_DIR / "Processed"
PROC_DAWN_DIR = PROCESSED_DATASETS_DIR / "DAWN"
PROC_ACDC_DIR = PROCESSED_DATASETS_DIR / "ACDC"
PROC_BDD100K_DIR = PROCESSED_DATASETS_DIR / "BDD100K"

# Results folders
YOLO_RESULTS_DIR = RESULTS_DIR / "YOLO"
FRCNN_RESULTS_DIR = RESULTS_DIR / "FasterRCNN"
COMPARISON_RESULTS_DIR = RESULTS_DIR / "Comparison"
VIDEO_RESULTS_DIR = RESULTS_DIR / "VideoValidation"

# Run folders
YOLO_RUNS_DIR = RUNS_DIR / "YOLO"
FRCNN_RUNS_DIR = RUNS_DIR / "FasterRCNN"

for folder in [
    RAW_DATASETS_DIR,
    RAW_DAWN_DIR,
    RAW_ACDC_DIR,
    RAW_BDD100K_DIR,
    PROCESSED_DATASETS_DIR,
    PROC_DAWN_DIR,
    PROC_ACDC_DIR,
    PROC_BDD100K_DIR
]:
    folder.mkdir(parents=True, exist_ok=True)

print("Detailed project structure ready.")
# Out:
# Detailed project structure ready.

# %% [markdown]
# ## Set Global Seed

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    # For reproducibility
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)
print("Global seed set to 42.")
# Out:
# Global seed set to 42.

# %% [markdown]
# ## Define Experiment Seeds

# %%
EXPERIMENT_SEEDS = [42, 123, 456]
print("Experiment seeds:", EXPERIMENT_SEEDS)
# Out:
# Experiment seeds: [42, 123, 456]

# %% [markdown]
# ## Select Compute Device

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Selected device:", DEVICE)
# Out:
# Selected device: cuda

# %% [markdown]
# ## **Environment Summary**

# %%
print("\n ENVIRONMENT SETUP COMPLETE ")
print(f"Device            : {DEVICE}")
print(f"PyTorch           : {torch.__version__}")
print(f"CUDA available    : {torch.cuda.is_available()}")
print(f"Project root      : {PROJECT_ROOT}")
print(f"Experiment seeds  : {EXPERIMENT_SEEDS}")
print("Environment setup completed successfully.")
# Out:
#  ENVIRONMENT SETUP COMPLETE
# Device            : cuda
# PyTorch           : 2.10.0+cu128
# CUDA available    : True
# Project root      : /content/drive/MyDrive/Colab Notebooks/Dissertation
# Experiment seeds  : [42, 123, 456]
# Environment setup completed successfully.
