# %% [markdown]
# ### Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Download from Kaggle

# %%
import kagglehub

path = kagglehub.dataset_download("yuetoken12/15-9gdiedie")
print(path)
# Out:
# ...
# 100%|██████████| 15.6G/15.6G [03:09<00:00, 88.7MB/s]
# Extracting files...
# /root/.cache/kagglehub/datasets/yuetoken12/15-9gdiedie/versions/1

# %% [markdown]
# ### Copy to drive (save permanently)

# %%
import os
os.makedirs("/content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC", exist_ok=True)

# %%
import shutil

shutil.copytree(
    path,
    "/content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC",
    dirs_exist_ok=True
)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC'

# %%
# !ls /root/.cache/kagglehub/
# Out:
# datasets

# %%
# !find "/content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC/rgb_anon" -maxdepth 2 -type d | sort
# Out:
# /content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC/rgb_anon
# /content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC/rgb_anon/fog
# /content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/test
# /content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/test_ref
# /content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/train
# /content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/train_ref
# /content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/val
# /content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/val_ref
# /content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC/rgb_anon/night
# /content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC/rgb_anon/night/test
# /content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC/rgb_anon/night/test_ref
# ...

# %%
# !du -sh "/content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC"
# Out:
# 16G	/content/drive/MyDrive/Colab Notebooks/Dissertation/Datasets/raw/ACDC

# %% [markdown]
# ### Download annotations

# %%
from pathlib import Path

PROJECT_ROOT = Path("/content/drive/MyDrive/Dissertation")

ACDC_ROOT = PROJECT_ROOT / "Datasets/raw/ACDC"
ACDC_ROOT.mkdir(parents=True, exist_ok=True)

# %cd $ACDC_ROOT
# Out:
# /content/drive/.shortcut-targets-by-id/17lufoiYQdFrVMwNFeK91HKX-sBA0zN4V/Dissertation/Datasets/raw/ACDC

# %%
# !wget https://acdc.vision.ee.ethz.ch/gt_detection_trainval.zip
# Out:
# --2026-05-12 19:22:47--  https://acdc.vision.ee.ethz.ch/gt_detection_trainval.zip
# Resolving acdc.vision.ee.ethz.ch (acdc.vision.ee.ethz.ch)... 129.132.159.36, 2001:67c:10ec:36c5::236
# Connecting to acdc.vision.ee.ethz.ch (acdc.vision.ee.ethz.ch)|129.132.159.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4637 (4.5K) [text/html]
# Saving to: ‘gt_detection_trainval.zip’
#
# gt_detection_trainv 100%[===================>]   4.53K  --.-KB/s    in 0s
#
# 2026-05-12 19:22:48 (565 MB/s) - ‘gt_detection_trainval.zip’ saved [4637/4637]

# %%
# !unzip gt_detection_trainval.zip
# Out:
# Archive:  gt_detection_trainval.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of gt_detection_trainval.zip or
#         gt_detection_trainval.zip.zip, and cannot find gt_detection_trainval.zip.ZIP, period.

# %% [markdown]
# ### Check folders imported

# %%
# !ls
# Out:
# gt_detection_trainval.zip  License.pdf	README.md  rgb_anon  taille_acdc.ipynb

# %%
# !find "/content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/gt_detection" -maxdepth 3 -type d | sort
# Out:
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/gt_detection
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/gt_detection/fog
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/gt_detection/night
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/gt_detection/rain
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/gt_detection/snow

# %%
# !find "/content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon" -maxdepth 3 -type d | sort
# Out:
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon/fog
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/test
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/test/GOPR0475
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/test/GOPR0477
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/test/GOPR0478
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/test/GP010475
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/test/GP010477
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/test/GP010478
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/test/GP020478
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/test_ref
# /content/drive/MyDrive/Dissertation/Datasets/raw/ACDC/rgb_anon/fog/test_ref/GOPR0475
# ...
